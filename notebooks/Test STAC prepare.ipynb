# %%
# %load_ext autoreload
from satsearch import Search
import json
from ls_public_bucket import make_stac_metadata_doc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lon_min = -180
lon_max = 180
lat_min = -90
lat_max = 90

start_date = '2020-02-01'
end_date = '2020-02-01'

extent = [lon_min, lat_min, lon_max, lat_max]

srch = Search().search(
        bbox=extent,
        datetime='{}T00:00:00Z/{}T23:59:59Z'.format(start_date, end_date),
        collections=["sentinel-s2-l2a-cogs"],
    )

# %%
srch.found()
# Out:
# 40

# %%
for item in srch.items():
    stac_item = item
    print(item)
    break
# Out:
# S2A_30NVL_20200201_0_L2A

# %%
item.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-3.1187658103746823, 4.434903832916533],
#    [-2.9119131922603363, 5.377969472742442],
#    [-2.912036742945311, 4.434908145738972],
#    [-3.1187658103746823, 4.434903832916533]]]}

# %%
print(json.dumps(stac_item.properties, indent=2))
print(json.dumps(stac_item.assets, indent=2))
# Out:
# {
#   "datetime": "2020-02-01T10:39:44.368000+00:00",
#   "platform": "sentinel-2a",
#   "constellation": "sentinel-2",
#   "instruments": [
#     "msi"
#   ],
#   "gsd": 10,
#   "view:off_nadir": 0,
#   "eo:cloud_cover": 0,
#   "proj:epsg": 32630,
#   "sentinel:latitude_band": "N",
#   "sentinel:grid_square": "VL",
#   "sentinel:sequence": "0",
#   "sentinel:product_id": "S2A_MSIL2A_20200201T102241_N0213_R065_T30NVL_20200201T123226",
#   "created": "2020-05-07T06:24:30.382Z",
#   "updated": "2020-05-07T06:24:30.382Z"
# }
# {
#   "thumbnail": {
#     "title": "Thumbnail",
#     "type": "image/png",
#     "href": "https://roda.sentinel-hub.com/sentinel-s2-l1c/tiles/30/N/VL/2020/2/1/0/preview.jpg"
#   },
#   "overview": {
#     "title": "True color image",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/L2A_PVI.tif",
#     "proj:shape": [
#       343,
#       343
#     ],
#     "proj:transform": [
#       320,
#       0,
#       399960,
#       0,
#       -320,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "info": {
#     "title": "Original JSON metadata",
#     "type": "application/json",
#     "href": "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/30/N/VL/2020/2/1/0/tileInfo.json"
#   },
#   "metadata": {
#     "title": "Original XML metadata",
#     "type": "application/xml",
#     "href": "https://roda.sentinel-hub.com/sentinel-s2-l2a/tiles/30/N/VL/2020/2/1/0/metadata.xml"
#   },
#   "visual": {
#     "title": "True color image",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/TCI.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B01": {
#     "title": "Band 1 (coastal)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B01.tif",
#     "proj:shape": [
#       1830,
#       1830
#     ],
#     "proj:transform": [
#       60,
#       0,
#       399960,
#       0,
#       -60,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B02": {
#     "title": "Band 2 (blue)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B02.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B03": {
#     "title": "Band 3 (green)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B03.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B04": {
#     "title": "Band 4 (red)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B04.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B05": {
#     "title": "Band 5",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B05.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B06": {
#     "title": "Band 6",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B06.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B07": {
#     "title": "Band 7",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B07.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B08": {
#     "title": "Band 8 (nir)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B08.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B8A": {
#     "title": "Band 8A",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B8A.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B09": {
#     "title": "Band 9",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B09.tif",
#     "proj:shape": [
#       1830,
#       1830
#     ],
#     "proj:transform": [
#       60,
#       0,
#       399960,
#       0,
#       -60,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B11": {
#     "title": "Band 11 (swir16)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B11.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "B12": {
#     "title": "Band 12 (swir22)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/B12.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "AOT": {
#     "title": "Aerosol Optical Thickness (AOT)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/AOT.tif",
#     "proj:shape": [
#       1830,
#       1830
#     ],
#     "proj:transform": [
#       60,
#       0,
#       399960,
#       0,
#       -60,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "WVP": {
#     "title": "Water Vapour (WVP)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/WVP.tif",
#     "proj:shape": [
#       10980,
#       10980
#     ],
#     "proj:transform": [
#       10,
#       0,
#       399960,
#       0,
#       -10,
#       600000,
#       0,
#       0,
#       1
#     ]
#   },
#   "SCL": {
#     "title": "Scene Classification Map (SCL)",
#     "type": "image/tiff; application=geotiff; profile=cloud-optimized",
#     "href": "https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/2020/S2A_30NVL_20200201_0_L2A/SCL.tif",
#     "proj:shape": [
#       5490,
#       5490
#     ],
#     "proj:transform": [
#       20,
#       0,
#       399960,
#       0,
#       -20,
#       600000,
#       0,
#       0,
#       1
#     ]
#   }
# }

# %%
# %autoreload 2
odc_meta = make_stac_metadata_doc(stac_item)
print(json.dumps(odc_meta, indent=2))
# Out:
# 20-0-399960-0--20-600000-0-0-1
# 20-0-399960-0--20-600000-0-0-1
# {
#   "$schema": "https://schemas.opendatacube.org/dataset",
#   "id": "1423c5d2-a00a-5cc2-9af5-ffebed7ac124",
#   "crs": "epsg:32630",
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           -3.1187658103746823,
#           4.434903832916533
#         ],
#         [
#           -2.9119131922603363,
#           5.377969472742442
#         ],
#         [
#           -2.912036742945311,
#           4.434908145738972
#         ],
#         [
#           -3.1187658103746823,
#           4.434903832916533
#         ]
#       ]
#     ]
#   },
#   "grids": {
#     "grid_2": {
#       "shape": [
#         1830,
#         1830
#       ],
#       "transform": [
#         60,
#         0,
#         399960,
#         0,
#         -60,
#         600000,
#         0,
#         0,
#         1
#       ]
#     },
#     "grid_3": {
#       "shape": [
#         10980,
#         10980
#       ],
#       "transform": [
#         10,
#         0,
#         399960,
#         0,
#         -10,
#         600000,
#         0,
#         0,
#         1
#       ]
#     },
#     "default": {
#       "shape": [
#         5490,
#         5490
#       ],
#       "transform": [
#         20,
#         0,
#         399960,
#         0,
#         -20,
#         600000,
#         0,
#         0,
#         1
#       ]
#     }
#   },
#   "product": {
#     "name": "s2a_msil2a"
#   },
#   "label": "S2A_MSIL2A_20200201T102241_N0213_R065_T30NVL_20200201T123226",
#   "properties": {
#     "datetime": "2020-02-01T10:39:44.368Z",
#     "odc:processing_datetime": "2020-02-01T10:39:44.368Z",
#     "eo:cloud_cover": 0,
#     "eo:gsd": 10,
#     "eo:instrument": "msi",
#     "eo:platform": "sentinel-2a",
#     "odc:file_format": "GeoTIFF",
#     "odc:region_code": "3NVL"
#   },
#   "measurements": {
#     "coastal_aerosol": {
#       "path": "B01.tif",
#       "grid": "60-0-399960-0--60-600000-0-0-1"
#     },
#     "blue": {
#       "path": "B02.tif",
#       "grid": "10-0-399960-0--10-600000-0-0-1"
#     },
#     "green": {
#       "path": "B03.tif",
#       "grid": "10-0-399960-0--10-600000-0-0-1"
#     },
#     "red": {
#       "path": "B04.tif",
#       "grid": "10-0-399960-0--10-600000-0-0-1"
#     },
#     "red_edge_1": {
#       "path": "B05.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "red_edge_2": {
#       "path": "B06.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "red_edge_3": {
#       "path": "B07.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "nir_1": {
#       "path": "B08.tif",
#       "grid": "10-0-399960-0--10-600000-0-0-1"
#     },
#     "nir_2": {
#       "path": "B8A.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "water_vapour": {
#       "path": "B09.tif",
#       "grid": "60-0-399960-0--60-600000-0-0-1"
#     },
#     "swir_1": {
#       "path": "B11.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "swir_2": {
#       "path": "B12.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     },
#     "scl": {
#       "path": "SCL.tif",
#       "grid": "20-0-399960-0--20-600000-0-0-1"
#     }
#   },
#   "lineage": {},
#   "grid_spatial": {
#     "projection": {
#       "spatial_reference": "epsg:32630",
#       "geo_ref_points": {
#         "ul": {
#           "x": 399960.0,
#           "y": 600000.0
#         },
#         "ur": {
#           "x": 509760.0,
#           "y": 600000.0
#         },
#         "lr": {
#           "x": 509760.0,
#           "y": 490200.0
#         },
#         "ll": {
#           "x": 399960.0,
#           "y": 490200.0
#         }
#       },
#       "valid_data": {
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -3.1187658103746823,
#               4.434903832916533
#             ],
#             [
#               -2.9119131922603363,
#               5.377969472742442
#             ],
#             [
#               -2.912036742945311,
#               4.434908145738972
#             ],
#             [
#               -3.1187658103746823,
#               4.434903832916533
#             ]
#           ]
#         ]
#       }
#     }
#   },
#   "extent": {
#     "lat": {
#       "begin": 4.000006280577471e-05,
#       "end": 4.8505926020428805e-05
#     },
#     "lon": {
#       "begin": -7.488771825400284,
#       "end": -7.488769972208944
#     }
#   }
# }
